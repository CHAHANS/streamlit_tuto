# %%
#확인용 파일
import streamlit
import pandas as pd

# %%
data = pd.read_csv('./TB_RECIPE_SEARCH-220701.csv', encoding='cp949')

# %%
search = '당근'

# %%
data['CKG_MTRL_CN']
# Out:
# <bound method Series.isnull of 0         [재료] 어묵 2개| 김밥용김 3장| 당면 1움큼| 양파 1/2개| 당근 1/2개|...
# 1         [재료] 두부 1/2모| 당근 1/2개| 고추 2개| 브로콜리 1/4개| 새우 4마...
# 2         [재료] 밥 1+1/2공기| 당근 1/4개| 치자단무지 1/2개| 신김치 1쪽| 무...
# 3                  [재료] 현미 4컵| 찹쌀 2컵| 호두 50g| 물 1/2컵| 소금 약간
# 4         [재료] 북어포 1마리| 찹쌀가루 1C [양념] 간장 2T| 설탕 1T| 물 1T|...
#                                 ...
# 128395    [재료] 양배추 1/4통| 양파 1/2개| 편마늘 1숟가락| 식용유 적당히| 물 2...
# 128396    [재료] 박력분 200g| 버터 70g| 크림치즈 70g| 설탕 100g| 계란 1...
# 128397    [재료] 포항초 300g| 건다시마 작은크기4~5장| 다시멸치 1줌| 홍고추 1개|...
# 128398    [재료] 식빵 4장| 감자 2개| 양파 1/4개| 피망 1/4개| 계란 2개| 치즈...
# 128399    [재료] 배추잎 8~10장| 홍고추 1개| 계란 2개 [양념] 부침가루(메밀) 5큰...
# Name: CKG_MTRL_CN, Length: 128400, dtype: object>

# %%
data.head()
# Out:
#    RCP_SNO          RCP_TTL CKG_NM   RGTR_ID RGTR_NM  INQ_CNT  RCMM_CNT  \
# 0   128671            어묵김말이  어묵김말이  skfo0701      꽃날     9592         6
# 1   128892  두부에 꼬리가 달렸어요!!     NaN  skfo0701      꽃날     5538         3
# 2   128932        입안에서 톡톡톡     NaN  skfo0701      꽃날     6802         8
# 3   131871           ★현미호두죽  현미호두죽   cds1117   햇님&별님     2912         0
# 4   139247  부들부들 보들보들 북어갈비♥   북어갈비  skfo0701      꽃날     6865         3
#
#    SRAP_CNT CKG_MTH_ACTO_NM CKG_STA_ACTO_NM CKG_MTRL_ACTO_NM CKG_KND_ACTO_NM  \
# 0        66              튀김              간식            가공식품류             디저트
# 1        26              부침              일상              해물류             밑반찬
# 2        36              굽기              일상              해물류           밥/죽/떡
# 3         9             끓이기              일상                쌀           밥/죽/떡
# 4        97              굽기             술안주             건어물류            메인반찬
#
#                                             CKG_IPDC  \
# ...

# %%
# df.query('주소.str.contains("서울")')
data.query('CKG_NM in "당근"')
# Out:
#         RCP_SNO                                    RCP_TTL CKG_NM   RGTR_ID  \
# 51554   6862719                              당근 모양내기(벚꽃모양)     당근  28478456
# 51589   6862761                  당근 나비 모양내기~~~ 일식조리기능사 연습용     당근  28478456
# 58378   6871207  몸에좋은 당근을 색다르게 즐기는방법 식이섬유가 풍부한 당근을 리큅에 말려요     당근  55225306
# 101025  6922201                     당근 보관법 3가지 채소 야채 보관방법      당근  32061214
# 111091  6933452                     눈건강에 좋은 당근을 말려서 드셔보세용~     당근  37279613
#
#            RGTR_NM  INQ_CNT  RCMM_CNT  SRAP_CNT CKG_MTH_ACTO_NM  \
# 51554       현이민이아빠    13994         5       207             데치기
# 51589       현이민이아빠     6122         3        68               회
# 58378          노루네     3596         0         7              기타
# 101025      햇살머금은집     3868         0        39              기타
# 111091  왕눈이의맛있는이야기     2029         0         7              기타
#
#        CKG_STA_ACTO_NM CKG_MTRL_ACTO_NM CKG_KND_ACTO_NM  \
# 51554               기타              채소류              기타
# ...

# %%
data['CKG_NM'].value_counts()
# Out:
# 두부조림        435
# 잡채          377
# 닭볶음탕        371
# 떡볶이         345
# 제육볶음        326
#            ...
# 연어두부볼         1
# 계란어묵탕         1
# 모카시나몬롤        1
# 닭가슴살김치볶음      1
# 양배추스프커리       1
# Name: CKG_NM, Length: 38567, dtype: int64

# %%
data['result'][0]
# Out:
# '[재료] 어묵 2개| 김밥용김 3장| 당면 1움큼| 양파 1/2개| 당근 1/2개| 깻잎 6장| 튀김가루 1컵 | 올리브유 적당량| 간장 1T| 참기름 1T'

# %%
data.head()
# Out:
#    RCP_SNO          RCP_TTL CKG_NM   RGTR_ID RGTR_NM  INQ_CNT  RCMM_CNT  \
# 0   128671            어묵김말이  어묵김말이  skfo0701      꽃날     9592         6
# 1   128892  두부에 꼬리가 달렸어요!!     NaN  skfo0701      꽃날     5538         3
# 2   128932        입안에서 톡톡톡     NaN  skfo0701      꽃날     6802         8
# 3   131871           ★현미호두죽  현미호두죽   cds1117   햇님&별님     2912         0
# 4   139247  부들부들 보들보들 북어갈비♥   북어갈비  skfo0701      꽃날     6865         3
#
#    SRAP_CNT CKG_MTH_ACTO_NM CKG_STA_ACTO_NM CKG_MTRL_ACTO_NM CKG_KND_ACTO_NM  \
# 0        66              튀김              간식            가공식품류             디저트
# 1        26              부침              일상              해물류             밑반찬
# 2        36              굽기              일상              해물류           밥/죽/떡
# 3         9             끓이기              일상                쌀           밥/죽/떡
# 4        97              굽기             술안주             건어물류            메인반찬
#
#                                             CKG_IPDC  \
# ...

# %% [markdown]
# # 숏츠 테스트

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
main_url = 'https://www.youtube.com/results?search_query='+'불고기'+' 레시피'
short_html = requests.get(main_url)
short = bs(short_html.text, "html.parser")

# %%
main_url = 'https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword='+'불고기'+' 레시피'
naver_html = requests.get(main_url)
naver = bs(naver_html.text, "html.parser")

# %%
naver
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <base href="/home"/>
# <meta content="noindex,nofollow" name="robots">
# <meta content="always" name="referrer"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://section.blog.naver.com/favicon.ico?3" rel="shortcut icon" type="image/x-icon"/>
# <meta content="불고기 레시피 : 네이버 블로그" property="og:title">
# <meta content="https://blogimgs.pstatic.net/nblog/mylog/post/og_default_image_160610.png" property="og:image"/>
# <meta content="당신의 모든 기록을 담는 공간" property="og:description"/>
# <meta content="blog" property="me:feed:serviceId"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>네이버 블로그</title>
# <link charset="UTF-8" href="https://ssl.pstatic.net/t.static.blog/section/versioning/section_ngapp-303295469_https.css" rel="stylesheet" type="text/css"/>
# <script>
# ...
